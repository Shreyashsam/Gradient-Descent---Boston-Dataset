# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
stand_sc=preprocessing.StandardScaler()

# %%
data = pd.read_csv("Train_boston.csv", delimiter=",")
data.shape
# stand_sc.fit(data)
data
# Out:
#        # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT     Y
# ...

# %%
stand_sc.fit(data)
# Out:
# StandardScaler()

# %%
Y=data[' Y']
del data[' Y']

# %%
lc=np.ones(data.shape[0])
lc.shape
data['lc']=1
data
# Out:
#        # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT  lc
# ...

# %%
points=np.array(data)
points.shape
points
# Out:
# array([[-0.40784991, -0.48772236, -1.2660231 , ...,  0.41057102,
#         -1.09799011,  1.        ],
#        [-0.40737368, -0.48772236,  0.24705682, ...,  0.29116915,
#         -0.52047412,  1.        ],
#        [ 0.1251786 , -0.48772236,  1.01599907, ..., -3.79579542,
#          0.89107588,  1.        ],
#        ...,
#        [-0.40831101, -0.48772236,  0.24705682, ...,  0.33206621,
#         -0.33404299,  1.        ],
#        [-0.41061997, -0.48772236, -1.15221381, ...,  0.203235  ,
#         -0.74475218,  1.        ],
#        [ 0.34290895, -0.48772236,  1.01599907, ...,  0.38787479,
#         -1.35871335,  1.        ]])

# %%
print(points.shape)
print(Y.shape)
# Out:
# (379, 14)
# (379,)

# %%
def step_gradient(points, learning_rate, m):
    m_slope = np.zeros(14)
    M = len(points)
    for i in range(M):
        x = points[i]
        y = Y[i]
        for j in range(14):
            m_slope[j] = m_slope[j]+(-2/M)* (y - (m * x).sum() )*x[j]
    for j in range(14):
        m[j] = m[j] - learning_rate*m_slope[j]
    return m

# %%
def gd(points, learning_rate, num_iterations):
    m=np.zeros(14)
    for i in range(num_iterations):
        m = step_gradient(points, learning_rate, m)
        print(i, " Cost: ", cost(points, m))
    return m

# %%
def cost(points, m):
    total_cost = 0
    M = len(points)
    for i in range(M):
        x = points[i]
        y = Y[i]
        total_cost += (1/M)*((y - (m*x).sum() )**2)
    return total_cost

# %%
def run():
    learning_rate = 0.1
    num_iterations = 1500
    m = gd(points, learning_rate, num_iterations)
    print(m)
    return m

# %%
m=run()
# Out:
# 0  Cost:  374.24035597919686
# 1  Cost:  245.37909656079904
# 2  Cost:  165.10614192173668
# 3  Cost:  114.49508621191686
# 4  Cost:  82.43432664281796
# 5  Cost:  62.041704688310936
# 6  Cost:  49.0154746660482
# 7  Cost:  40.65519326019772
# 8  Cost:  35.25972835067592
# 9  Cost:  31.754121492629718
# 10  Cost:  29.457161634001743
# 11  Cost:  27.936007022144533
# 12  Cost:  26.914922412896374
# 13  Cost:  26.217802951980175
# 14  Cost:  25.731872822963105
# 15  Cost:  25.38469911771804
# 16  Cost:  25.129603525591076
# 17  Cost:  24.936384410518777
# 18  Cost:  24.785404792037365
# 19  Cost:  24.66381822190748
# 20  Cost:  24.56315514362143
# 21  Cost:  24.477776518190055
# 22  Cost:  24.403881200700226
# 23  Cost:  24.338867434896198
# 24  Cost:  24.280921148348455
# 25  Cost:  24.228749732407817
# 26  Cost:  24.18140930058519
# 27  Cost:  24.138192120101166
# 28  Cost:  24.09855285948923
# 29  Cost:  24.06205993819115
# 30  Cost:  24.028363158977218
# ...

# %%
# m=np.around(m,decimals=5)
m.shape
# Out:
# (14,)

# %%
data_test1=pd.read_csv('Test_boston.csv')
data_test1['C']=1
data_test1.shape
# Out:
# (127, 14)

# %%
Testing1=np.array(data_test1)

# %%
y_Test_predict=[]
for i in range(len(data_test1)):
  X=Testing1[i,:15]
  y=(m*X).sum()
  y_Test_predict.append(y)

# %%
y_Test_predict=np.array(y_Test_predict)
y_Test_predict=np.around(y_Test_predict,decimals=5)
y_Test_predict
# Out:
# array([12.43328, 29.03367, 22.37164, 24.47779, 20.60167,  2.72533,
#        30.4    , 24.8612 , 18.65725, 23.53986, 24.11397, 17.71144,
#        17.44   , 21.65356, 42.31138, 23.84974, 24.47573, 27.53873,
#        20.23607, 31.15155, 23.78238, 25.00979, 33.95769, 36.43516,
#        32.04098, 16.71323, 23.47177, 32.93828, 25.1807 , 33.71009,
#        16.8858 , 26.02761, 23.2704 , 25.47759, 15.00947, 29.58575,
#        26.24821, 20.37246, 24.43681,  9.44707,  8.38097, 29.01392,
#        29.59085, 19.75757, 20.37197,  3.14443, 39.5242 , 25.71741,
#        30.3773 , 16.79453, 17.89089, 41.02575, 17.57239, 20.89663,
#        15.59838, 21.41395, 18.45436, 23.15576, 13.67245, 17.23574,
#        15.0271 , 29.15131, 25.17166, 25.49749, 17.21187, 17.42937,
#        34.70373, 17.01341, 27.10724, 22.54696, 29.25337, 27.11018,
#        17.73402,  5.74705, 36.87654, 25.09194, 30.15054, 27.24081,
#        16.25218, 32.63542, 19.27351, 22.65417, 22.22935,  8.55085,
# ...

# %%
np.savetxt('Final_prediction7878.csv',y_Test_predict,delimiter=",",fmt='%f')
